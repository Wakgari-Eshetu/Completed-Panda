# %%
import pandas as pd 
df = pd.read_csv('../../data/practice3.csv')
df.head()
# Out:
#     Age  Experience   Salary Score  Projects  Rating Department  Gender  \
# 0  25.0         2.0  40000.0    85       2.0     4.5         HR    Male
# 1  30.0         5.0  55000.0    90       5.0     4.8         IT  Female
# 2  28.0         4.0      NaN    88       4.0     4.6    Finance  Female
# 3  26.0         3.0  42000.0    82       3.0     4.2         HR    Male
# 4   NaN         6.0  60000.0    95       6.0     4.9         IT    Male
#
#    Education     Location
# 0  Bachelors  Addis Ababa
# 1    Masters        Adama
# 2  Bachelors    Bahir Dar
# 3  Bachelors  Addis Ababa
# 4    Masters        Adama

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         29 non-null     float64
#  1   Experience  29 non-null     float64
#  2   Salary      27 non-null     float64
#  3   Score       30 non-null     object
#  4   Projects    29 non-null     float64
#  5   Rating      29 non-null     float64
#  6   Department  30 non-null     object
#  7   Gender      29 non-null     object
#  8   Education   29 non-null     object
#  9   Location    30 non-null     object
# dtypes: float64(5), object(5)
# memory usage: 2.5+ KB

# %%
# DataInforcement 
df['Score'] = pd.to_numeric(df['Score'] , errors='coerce')
df['Score'].dtypes
# Out:
# dtype('float64')

# %%
df.isnull().sum()
# Out:
# Age           1
# Experience    1
# Salary        3
# Score         1
# Projects      1
# Rating        1
# Department    0
# Gender        1
# Education     1
# Location      0
# dtype: int64

# %%
# classify the data set as numerical and categorical 
num_cols = df.select_dtypes(include='number').columns
cat_cols = df.select_dtypes(include='object').columns


print(df[num_cols].isnull().mean() * 100)
print("------------------------------")
print(df[cat_cols].isnull().mean() * 100)
# Out:
# Age            3.333333
# Experience     3.333333
# Salary        10.000000
# Score          3.333333
# Projects       3.333333
# Rating         3.333333
# dtype: float64
# ------------------------------
# Department    0.000000
# Gender        3.333333
# Education     3.333333
# Location      0.000000
# dtype: float64
