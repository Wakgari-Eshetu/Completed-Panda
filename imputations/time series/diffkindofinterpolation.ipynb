# %%
import pandas as pd
import numpy as np

np.random.seed(42)

# Create a date index (100 days)
dates = pd.date_range(start="2024-01-01", periods=100, freq="D")

# Create synthetic data
data = {
    f"sensor{i}": np.random.normal(loc=50 + i*5, scale=10, size=100) 
    for i in range(1, 6)
}

# Add some irregular patterns
for i in range(1, 6):
    data[f"signal{chr(64+i)}"] = (
        np.linspace(10*i, 10*i + 100, 100) 
        + np.random.normal(scale=15, size=100)
    )

df = pd.DataFrame(data, index=dates)

# Introduce random missing values (~15-20%)
for col in df.columns:
    missing_indices = np.random.choice(df.index, size=int(0.17*len(df)), replace=False)
    df.loc[missing_indices, col] = np.nan

# Show first 10 rows
print(df.head(10))
# Out:
#               sensor1    sensor2    sensor3    sensor4    sensor5    signalA  \
# 2024-01-01        NaN  45.846293  68.577874  61.710050        NaN  23.892663
# 2024-01-02  53.617357  55.793547  70.607845  64.398190  69.006250  39.651351
# 2024-01-03  61.476885  56.572855  75.830512        NaN  75.052437  -8.958312
# 2024-01-04  70.230299        NaN  75.538021  76.103703  75.469806        NaN
# 2024-01-05  52.658466  58.387143  51.223306  69.790984  70.499345        NaN
# 2024-01-06  52.658630  64.040509  55.621750        NaN  81.228499   7.743624
# 2024-01-07  70.792128        NaN  70.150353  82.776649  64.323796   7.174697
# 2024-01-08  62.674347  61.745778  70.137860  64.084286  73.576205   4.110846
# 2024-01-09  50.305256  62.575504  70.150477  75.470974  76.202956  18.808632
# 2024-01-10  60.425600  59.255541        NaN  67.978073  80.144388   6.626657
#
#               signalB    signalC    signalD    signalE
# 2024-01-01  31.354829  22.159155  54.074257        NaN
# 2024-01-02   7.177621  46.745239  33.269430        NaN
# 2024-01-03  35.064291  21.455047  43.462014  52.451374
# 2024-01-04  43.364871  11.903384  36.096174  72.207081
# 2024-01-05  30.241928  10.690966  37.522961  56.906890
# 2024-01-06  53.202442        NaN  40.412923  55.747053
# 2024-01-07  14.453768  16.854166  49.392613        NaN
# 2024-01-08   8.400887  63.392620  39.889478        NaN
# 2024-01-09   1.400004   6.851867  66.917150  67.763071
# 2024-01-10  51.531574  64.537755  35.671800  91.539730

# %%
# using polynomial and spine etc 

df.interpolate(method='polynomial' , order= 3).bfill().ffill()
# or df.interpolate(method='spine',order = 2,3,4,5,7)
# Out:
#               sensor1    sensor2    sensor3     sensor4    sensor5  \
# 2024-01-01  53.617357  45.846293  68.577874   61.710050  69.006250
# 2024-01-02  53.617357  55.793547  70.607845   64.398190  69.006250
# 2024-01-03  61.476885  56.572855  75.830512   73.544089  75.052437
# 2024-01-04  70.230299  55.984360  75.538021   76.103703  75.469806
# 2024-01-05  52.658466  58.387143  51.223306   69.790984  70.499345
# ...               ...        ...        ...         ...        ...
# 2024-04-05  53.724507  63.853174  58.070904   57.633478  80.389100
# 2024-04-06  57.961203  51.161426  59.822932   52.868655  73.963559
# 2024-04-07  57.610553  61.537251  68.072995   83.538724  73.096613
# 2024-04-08  55.051135  60.582087  73.128621  110.868232  66.243817
# 2024-04-09  52.654129  60.582087  71.296288   82.378163  61.172003
#
#                signalA     signalB     signalC     signalD     signalE
# 2024-01-01   23.892663   31.354829   22.159155   54.074257   52.451374
# 2024-01-02   39.651351    7.177621   46.745239   33.269430   52.451374
# 2024-01-03   -8.958312   35.064291   21.455047   43.462014   52.451374
# 2024-01-04  -24.441112   43.364871   11.903384   36.096174   72.207081
# 2024-01-05   -9.586802   30.241928   10.690966   37.522961   56.906890
# ...                ...         ...         ...         ...         ...
# 2024-04-05   98.309350  111.316399  141.756889  145.690244  141.743092
# 2024-04-06  102.921573  121.861692  126.376370  134.462926  173.934995
# 2024-04-07   93.298342   99.213094  138.202308  140.180503  157.592441
# 2024-04-08  102.325500  132.850304  129.414675  157.087533  129.835635
# 2024-04-09  115.659507  117.226468  129.414675  127.745965  158.588742
#
# [100 rows x 10 columns]
