# %%
#Accessing elements of series 
# access based on the index the pandas series is created
# posiotion based and label based indexing 
import pandas as pd 
data = [1,2,3,4,5]
ser = pd.Series(data , index= [4,5,6,7,8])
print(ser)

print(ser[4])
# Out:
# 4    1
# 5    2
# 6    3
# 7    4
# 8    5
# dtype: int64
# 1
